# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.size
# Out:
# 10692

# %%
data.Age.isnull().sum()
# Out:
# 177

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data.boxplot(figsize = (10,6) )

# %%
gender = {'male': 0,'female': 1} 
data.Sex = [gender[item] for item in data.Sex]

# %%
data.Embarked = data.Embarked.fillna('S')

# %%
emb = {'S': 0,'C': 1, 'Q' : 2} 
data.Embarked = [emb[item] for item in data.Embarked]

# %%
data.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
data.Age.isnull().sum()
# Out:
# 177

# %%
data.Age = data.Age.fillna(np.mean(data.Age))

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name  Sex        Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.000000      1
# ...

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(data['Fare'], data['PassengerId'])
ax.set_xlabel('Fare')
ax.set_ylabel('PI')
plt.show()

# %%
from scipy import stats
z = np.abs(stats.zscore(data.Fare))

# %%
lb = 0
ub = 0.97
res = data.Fare.quantile([lb, ub])
res
# Out:
# 0.00      0.00
# 0.97    151.55
# Name: Fare, dtype: float64

# %%
outmod = (res.loc[lb] < data.Fare.values) & (data.Fare.values < res.loc[ub])

# %%
outmod[1 : 50]
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
mid = np.mean(data.Fare[outmod])

# %%
mid
# Out:
# 25.63336186540727

# %%
def replace(group):
    mean, std = group.mean(), group.std()
    outliers = (group - mean).abs() > 3*std
    group[outliers] = mean
    return group

data.groupby('Fare')

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name  Sex        Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  22.000000      1
# ...

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(data['Fare'], data['PassengerId'])
ax.set_xlabel('Fare')
ax.set_ylabel('PI')
plt.show()

# %%
data.describe(include = ['O'])
# Out:
#                           Name    Ticket Cabin
# count                      891       891   204
# unique                     891       681   147
# top     Reed, Mr. James George  CA. 2343    G6
# freq                         1         7     4

# %%
data.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                    Name  \
# count    891.000000  891.000000  891.000000                     891
# unique          NaN         NaN         NaN                     891
# top             NaN         NaN         NaN  Reed, Mr. James George
# freq            NaN         NaN         NaN                       1
# mean     446.000000    0.383838    2.308642                     NaN
# std      257.353842    0.486592    0.836071                     NaN
# min        1.000000    0.000000    1.000000                     NaN
# 25%      223.500000    0.000000    2.000000                     NaN
# 50%      446.000000    0.000000    3.000000                     NaN
# 75%      668.500000    1.000000    3.000000                     NaN
# max      891.000000    1.000000    3.000000                     NaN
#
#                Sex         Age       SibSp       Parch    Ticket        Fare  \
# ...

# %%
data[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Sex  Survived
# 1    1  0.742038
# 0    0  0.188908

# %%
data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(data['Age'], data['PassengerId'])
ax.set_xlabel('Age')
ax.set_ylabel('PI')
plt.show()

# %%
x = data[['PassengerId', 'Sex', 'Age', 'Fare', 'Embarked' ]]
y = data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=3, solver='lbfgs',
                         multi_class='multinomial').fit(x_train, y_train)

# %%
t = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, t)
# Out:
# 0.7821229050279329

# %%
data.head(40)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...
